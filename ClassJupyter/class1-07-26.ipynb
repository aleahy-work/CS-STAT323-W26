# %%
1+1
# Out:
# 2

# %% [markdown]
# This is my text in support of my work.
#
# # This is big #
#
# ## This is biggish ##
#
# You can actually typeset mathematics very easily:
#
# $ \int x^2 dx$

# %% [markdown]
# 1+1
#
# $\sqrt{x^2 + 3 x + 1}$

# %%
import numpy as np

# %%
mylist =[1,2,3,4]

# %%
mylist**2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 mylist**2
#
# TypeError: unsupported operand type(s) for ** or pow(): 'list' and 'int'

# %%
mynump = np.array(mylist)

# %%
mynump
# Out:
# array([1, 2, 3, 4])

# %%
mynump**2
# Out:
# array([ 1,  4,  9, 16])

# %%
mylist[0]
# Out:
# 1

# %%
mylist[3]
# Out:
# 4

# %%
mylist
# Out:
# [1, 2, 3, 4]
