# %% [markdown]
# # Class 1/16/26 Notes #

# %%
import numpy as np

# %%
mymv = np.random.multivariate_normal([4,5], [[1,.9],[.9,1]], size=200, check_valid='warn', tol=1e-8)

# %%
mydata = np.transpose(mymv)

# %%
mymv[:,1]
# Out:
# array([5.22844202, 5.90232818, 4.7289218 , 5.28257145, 4.96303824,
#        4.27579277, 3.40766331, 5.40046001, 5.06156898, 4.82812967,
#        2.88245696, 5.63441606, 2.60138131, 3.65214139, 5.23935199,
#        4.11937911, 4.53610552, 3.95224432, 6.18581865, 5.82231637,
#        5.06908017, 4.04981597, 3.6457037 , 5.08525277, 3.31607774,
#        5.14493624, 4.58254151, 6.19390962, 4.76243429, 5.77328191,
#        4.77652988, 3.72579568, 4.16700475, 4.39569324, 5.9235819 ,
#        4.48274005, 4.48181478, 5.64560026, 4.84845115, 5.3525816 ,
#        3.88078868, 4.269119  , 4.50370608, 5.2648996 , 7.20033353,
#        5.99124341, 5.23223533, 6.74004102, 4.03978157, 5.11023616,
#        5.87394301, 3.01103224, 5.94001796, 5.30567538, 7.92739836,
#        5.27127518, 5.39764025, 5.34325569, 4.95769913, 5.22335759,
#        4.95284578, 3.84914156, 6.63102313, 4.34823872, 4.77431136,
#        4.19746819, 4.70860528, 3.86719296, 4.92650805, 5.69134219,
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
plt.scatter(mymv[:,0], mymv[:,1])

# %%
myxval = mymv[:,0]
myyval = mymv[:,1]

# %%
from sklearn.linear_model import LinearRegression

# %%
myxval.shape
# Out:
# (200,)

# %%
myyval.shape
# Out:
# (200,)

# %%
mymodel = LinearRegression().fit(myxval.reshape(-1,1), myyval.reshape(-1,1))

# %%
myxval.reshape(-1,1).shape
# Out:
# (200, 1)

# %%
myyval.reshape(-1,1).shape
# Out:
# (200, 1)

# %%
mymodel.coef_
# Out:
# array([[0.85431404]])

# %%
mymodel.intercept_
# Out:
# array([1.53783522])

# %%
mymodel.predict([[2]])
# Out:
# array([[3.24646331]])

# %%
mymodel.score(myxval.reshape(-1,1), myyval.reshape(-1,1))
# Out:
# 0.7673401508222671
