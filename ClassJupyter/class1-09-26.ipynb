# %%
print('*'*25)
print('**')
# Out:
# *************************
# **

# %% [markdown]
# ## Fun with Pandas ##

# %%
import pandas as pd

# %%
mydata = pd.read_csv('firstday2122.csv',index_col=0)

# %%
mydata.head(5)
# Out:
#    year  randnum diehard  earlobes            hitchthumb  age  siblings  \
# 1  2021      3.0     Yes  Detached     Hitchhikers thumb   19         1
# 2  2021      7.0     Yes  Attached     Hitchhikers thumb   21         0
# 3  2021      NaN      No  Detached  No hitchhikers thumb   19         2
# 4  2021      3.0      No  Detached  No hitchhikers thumb   19         0
# 5  2021      4.0     Yes  Detached  No hitchhikers thumb   20         1
#
#     pizzatop           knoxyear eyecolor cellphone   hand     sex  height  \
# 1  Pepperoni          Sophomore    Brown   Android  Right  Female    66.0
# 2     Cheese  Senior and beyond    Brown   Android   Left  Female    64.5
# 3     Cheese          Sophomore    Brown   Android  Right    Male    73.0
# 4     Cheese          Sophomore    Other   Android  Right    Male    67.0
# 5    Sausage             Junior    Brown   Android  Right  Female    64.8
#
#    wingspan  cubit  handspan
# 1      67.1   17.5       7.5
# ...

# %%
mydata.hasnans
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1352225/2918894213.py in ?()
# ----> 1 mydata.hasnans
#
# /opt/jupyterhub/jupyter_env/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'hasnans'

# %%
newdata = mydata[['randnum','diehard']]

# %%
newerdata = newdata.dropna()

# %%
newerdata.head(5)
# Out:
#    randnum diehard
# 1      3.0     Yes
# 2      7.0     Yes
# 4      3.0      No
# 5      4.0     Yes
# 6      6.0     Yes

# %%
mydata.head(5)
# Out:
#    year  randnum diehard  earlobes            hitchthumb  age  siblings  \
# 1  2021      3.0     Yes  Detached     Hitchhikers thumb   19         1
# 2  2021      7.0     Yes  Attached     Hitchhikers thumb   21         0
# 3  2021      NaN      No  Detached  No hitchhikers thumb   19         2
# 4  2021      3.0      No  Detached  No hitchhikers thumb   19         0
# 5  2021      4.0     Yes  Detached  No hitchhikers thumb   20         1
#
#     pizzatop           knoxyear eyecolor cellphone   hand     sex  height  \
# 1  Pepperoni          Sophomore    Brown   Android  Right  Female    66.0
# 2     Cheese  Senior and beyond    Brown   Android   Left  Female    64.5
# 3     Cheese          Sophomore    Brown   Android  Right    Male    73.0
# 4     Cheese          Sophomore    Other   Android  Right    Male    67.0
# 5    Sausage             Junior    Brown   Android  Right  Female    64.8
#
#    wingspan  cubit  handspan
# 1      67.1   17.5       7.5
# ...

# %%
mydata[mydata['sex'] == 'Female']
# Out:
#     year  randnum diehard  earlobes             hitchthumb  age  siblings  \
# 1   2021      3.0     Yes  Detached      Hitchhikers thumb   19         1
# 2   2021      7.0     Yes  Attached      Hitchhikers thumb   21         0
# 5   2021      4.0     Yes  Detached   No hitchhikers thumb   20         1
# 10  2021      2.0     Yes  Detached      Hitchhikers thumb   18         0
# 12  2021      5.0      No  Detached   No hitchhikers thumb   19         1
# 14  2021      3.0     Yes  Detached      Hitchhikers thumb   21         1
# 19  2021      3.0     Yes  Attached   No hitchhikers thumb   20         1
# 20  2021      8.0     Yes  Attached      Hitchhikers thumb   18         1
# 23  2021      8.0     Yes  Detached      Hitchhikers thumb   21         0
# 24  2021      6.0     Yes  Detached   No hitchhikers thumb   20         0
# 25  2021      6.0     Yes  Detached   No hitchhikers thumb   20         5
# 27  2021      2.0     Yes  Detached   No hitchhikers thumb   18         1
# ...

# %%
mydata[mydata['sex'] == 'Female'].dropna()
# Out:
#     year  randnum diehard  earlobes             hitchthumb  age  siblings  \
# 1   2021      3.0     Yes  Detached      Hitchhikers thumb   19         1
# 2   2021      7.0     Yes  Attached      Hitchhikers thumb   21         0
# 5   2021      4.0     Yes  Detached   No hitchhikers thumb   20         1
# 10  2021      2.0     Yes  Detached      Hitchhikers thumb   18         0
# 12  2021      5.0      No  Detached   No hitchhikers thumb   19         1
# 14  2021      3.0     Yes  Detached      Hitchhikers thumb   21         1
# 19  2021      3.0     Yes  Attached   No hitchhikers thumb   20         1
# 20  2021      8.0     Yes  Attached      Hitchhikers thumb   18         1
# 23  2021      8.0     Yes  Detached      Hitchhikers thumb   21         0
# 24  2021      6.0     Yes  Detached   No hitchhikers thumb   20         0
# 25  2021      6.0     Yes  Detached   No hitchhikers thumb   20         5
# 27  2021      2.0     Yes  Detached   No hitchhikers thumb   18         1
# ...

# %%
femaledata = mydata[mydata['sex'] == 'Female'].dropna()['height']

# %%
femaledata.mean()
# Out:
# np.float64(65.6576923076923)

# %%
femaledata.hist()
# Out:
# <Axes: >

# %%
mydata
# Out:
#     year  randnum diehard  earlobes             hitchthumb  age  siblings  \
# 1   2021      3.0     Yes  Detached      Hitchhikers thumb   19         1
# 2   2021      7.0     Yes  Attached      Hitchhikers thumb   21         0
# 3   2021      NaN      No  Detached   No hitchhikers thumb   19         2
# 4   2021      3.0      No  Detached   No hitchhikers thumb   19         0
# 5   2021      4.0     Yes  Detached   No hitchhikers thumb   20         1
# ..   ...      ...     ...       ...                    ...  ...       ...
# 59  2022      5.0      No  Detached  No hitchhiker's thumb   20         1
# 60  2022      8.0     Yes  Detached  No hitchhiker's thumb   18         0
# 61  2022      4.0      No  Detached  No hitchhiker's thumb   20         1
# 62  2022      8.0      No  Detached  No hitchhiker's thumb   20         2
# 63  2022      4.0     Yes  Attached     Hitchhiker's thumb   19         3
#
#      pizzatop           knoxyear eyecolor cellphone   hand     sex  height  \
# ...

# %%
mydata['pizzatop'].unique()
# Out:
# array(['Pepperoni', 'Cheese', 'Sausage', 'Other', 'Mushrooms'],
#       dtype=object)

# %%
mynewerdata = pd.read_csv('cropyields.csv')

# %%
mynewerdata.head(5)
# Out:
#   LOCATION  INDICATOR SUBJECT   MEASURE FREQUENCY  TIME  Value  Flag Codes
# 0      AUS  CROPYIELD    RICE  TONNE_HA         A  1990  8.315         NaN
# 1      AUS  CROPYIELD    RICE  TONNE_HA         A  1991  8.395         NaN
# 2      AUS  CROPYIELD    RICE  TONNE_HA         A  1992  8.094         NaN
# 3      AUS  CROPYIELD    RICE  TONNE_HA         A  1993  8.336         NaN
# 4      AUS  CROPYIELD    RICE  TONNE_HA         A  1994  8.538         NaN

# %%
mynewerdata.shape
# Out:
# (18676, 8)

# %% [markdown]
# # What are the average crop yields for rice in Vietnam for the time periods available? '

# %% [markdown]
# # Produce a side by side comparison (boxplot?) of the distribution of rice yields in Vietnam vs the rice yields in the USA for the time periods available #

# %%
mynewerdata['LOCATION'].unique()
# Out:
# array(['AUS', 'CAN', 'JPN', 'KOR', 'MEX', 'NZL', 'TUR', 'USA', 'ARG',
#        'BRA', 'CHL', 'CHN', 'COL', 'EGY', 'ETH', 'IND', 'IDN', 'IRN',
#        'KAZ', 'MYS', 'NGA', 'PAK', 'PRY', 'PER', 'PHL', 'RUS', 'SAU',
#        'ZAF', 'THA', 'UKR', 'VNM', 'WLD', 'OECD', 'BRICS', 'NOR', 'CHE',
#        'ISR', 'GBR'], dtype=object)

# %%
mynewerdata['SUBJECT'].unique()
# Out:
# array(['RICE', 'WHEAT', 'MAIZE', 'SOYBEAN'], dtype=object)
